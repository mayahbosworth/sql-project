# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# selenium web driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# set symbols
symbol = ["JPM", "GS", "C", "JLL", "DIS", "TPR", "F", "XOM", "AAPL", "AMZN", "PFE", "MRK"]

# insider transactions, trading volume, analyst ratings, price fluctuations, market capitalization
# Insider Transactions: Located under the "Holders" section, it lists the buys and sells by company insiders.
# Trading Volume: Found on the "Summary" and "Historical Data" pages, it shows the number of shares traded during a given period.
# Analyst Ratings: Located in the "Analysis" section, it provides the ratings and price targets set by financial analysts.
# INSIDER TRANSACTIONS: located under the "Holders" section, it lists the buys and sells by company insiders.

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the Selenium driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# URL to scrape
url = f'https://finance.yahoo.com/quote/{symbol}/insider-transactions'

# Open the URL
driver.get(url)

# Wait for the page to load
time.sleep(10)

# Find the table by class name (update class name to the one you found for the table)
insider_table = driver.find_element(By.CLASS_NAME, 'svelte-1s2g2l0')
# Find all the rows in the table
rows = insider_table.find_elements(By.TAG_NAME, 'tr')


# Extract the table headers
headers = [header.text for header in rows[0].find_elements(By.TAG_NAME, 'th')]

# Extract the table rows
data = []
for row in rows[1:]:  # Skip the header row
    cols = row.find_elements(By.TAG_NAME, 'td')
    row_data = [col.text for col in cols]
    data.append(row_data)

# Close the Selenium driver
driver.quit()

# Convert the data into a pandas DataFrame
insider_transactions_df = pd.DataFrame(data, columns=headers)

# Print the DataFrame
print(insider_transactions_df)
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the Selenium driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

symbol = 'AAPL'  # replace this with your desired ticker symbol
# Corrected URL with proper string formatting
url = f'https://finance.yahoo.com/quote/{symbol}/history?filter=history'

driver.get(url)  # Open the URL

# Wait for the page to load
time.sleep(6)

trading_volume_table = driver.find_element(By.CSS_SELECTOR, '.table.svelte-ewueuo')

# Find all the rows in the table
rows = trading_volume_table.find_elements(By.TAG_NAME, 'tr')

# Extract the table headers
headers = [header.text for header in rows[0].find_elements(By.TAG_NAME, 'th')]

# Extract the table rows
data = []
for row in rows[1:]:  # Skip the header row
    cols = row.find_elements(By.TAG_NAME, 'td')
    row_data = [col.text for col in cols]
    data.append(row_data)

# Close the Selenium driver
driver.quit()

# Convert the data into a pandas DataFrame
trading_volume_df = pd.DataFrame(data, columns=headers)

# Print the DataFrame
print(trading_volume_df)

# EARNINGS ESTIMATE
# ANALYST RATINGS: earnings estimate, eps trends, eps revisions, growth estimates

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the Selenium driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

symbol = 'AAPL'  # replace this with your desired ticker symbol
# Corrected URL with proper string formatting
url = f'https://finance.yahoo.com/quote/{symbol}/analysis'

driver.get(url)  # Open the URL

# Wait for the page to load
time.sleep(10)

# ... [your previous setup code] ...

# Function to extract table data
def extract_table_data(section):
    table = section.find_element(By.TAG_NAME, 'table')
    rows = table.find_elements(By.TAG_NAME, 'tr')
    headers = [header.text for header in rows[0].find_elements(By.TAG_NAME, 'th')]
    data = [[td.text for td in row.find_elements(By.TAG_NAME, 'td')] for row in rows[1:]]
    return pd.DataFrame(data, columns=headers)

# Earnings Estimate
section_earnings_estimate = driver.find_element(By.XPATH, '//section[@data-testid="earningsEstimate"]')
earnings_estimate_df = extract_table_data(section_earnings_estimate)

# EPS Trend
section_eps_trend = driver.find_element(By.XPATH, '//section[@data-testid="epsTrend"]')
eps_trend_df = extract_table_data(section_eps_trend)

# EPS Revisions
section_eps_revision = driver.find_element(By.XPATH, '//section[@data-testid="epsRevisions"]')
eps_revision_df = extract_table_data(section_eps_revision)

# Growth Estimates
section_growth_estimate = driver.find_element(By.XPATH, '//section[@data-testid="growthEstimate"]')
growth_estimate_df = extract_table_data(section_growth_estimate)

# Print the DataFrames
print("Earnings Estimate:")
print(earnings_estimate_df)
print("\nEPS Trend:")
print(eps_trend_df)
print("\nEPS Revisions:")
print(eps_revision_df)
print("\nGrowth Estimate:")
print(growth_estimate_df)

# Close the Selenium driver
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Set up the Selenium driver
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import os
from dotenv import load_dotenv
from sqlalchemy import create_engine
load_dotenv()

username = os.getenv('username')
password = os.getenv('password')
host = os.getenv('host')
port = os.getenv('port')
database = os.getenv('database')
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 port = os.getenv('port')
#      15 database = os.getenv('database')
# ---> 16 engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}:{port}/{database}')
#      18 service = Service(ChromeDriverManager().install())
#      19 driver = webdriver.Chrome(service=service)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:309, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     302     if m in kwargs:
#     303         _warn_with_version(
#     304             messages[m],
#     305             versions[m],
#     306             version_warnings[m],
#     307             stacklevel=3,
#     308         )
# --> 309 return fn(*args, **kwargs)
#
# ...

# %%
def extract_table_data(table_element):
    rows = table_element.find_elements(By.TAG_NAME, 'tr')
    headers = [header.text for header in rows[0].find_elements(By.TAG_NAME, 'th')]
    data = [[td.text for td in row.find_elements(By.TAG_NAME, 'td')] for row in rows[1:]]
    return pd.DataFrame(data, columns=headers)

def dataframe_to_sql(df, table_name, engine):
    df.to_sql(name=table_name, con=engine, if_exists='append', index=False)
